# %% [markdown]
# ## Matplot lib
#
# This file exists to practice using the Matplotlib library for animation and plotting in python. Created by Brian Lesko for the purposes of rapid prototyping software for control systems engineering, robotics engineering, and machine learning and AI development. Created 9/4/23 in the last semester of earning a Masters in Engineering with a specialization in autonomous systems at Ohio State University.

# %%
import numpy as np
import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits import mplot3d
#necessary for jupyter notebook interactive 

#plt.rcParams['figure.dpi'] = 300
#plt.rcParams['savefig.dpi'] = 300

from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg')

# the command to make a virtual env is: python3 -m venv env
# the command to activate the virtual env is: source env/bin/activate
# the command to add our libraries to the virtual env is: pip install numpy matplotlib
# Out:
# /var/folders/7y/6b82r8j576s0j4p84sz0f5dc0000gn/T/ipykernel_37762/749125133.py:11: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('svg')

# %%
# Single points 

ax = plt.axes(projection='3d')
ax.scatter(1, 2, 3, c='r', marker='o')
ax.scatter(3, 2, 1, c='b', marker='^')
ax.scatter(2, 3, 1, c='g', marker='*')
ax.scatter(2, 1, 3, c='y', marker='x')
ax.scatter(3, 1, 2, c='m', marker='D')
ax.scatter(1, 3, 2, c='c', marker='s')
ax.scatter(1, 1, 1, c='k', marker='p')
ax.scatter(3, 3, 3, c='r', marker='h')
ax.scatter(2, 2, 6, c='b', marker='H')
ax.scatter(2, 2, 1, c='g', marker='+')
ax.scatter(1, 2, 2, c='y', marker='d')
ax.scatter(2, 1, 2, c='m', marker='v')
ax.scatter(2, 3, 3, c='c', marker='1')

plt.show()

# %%
ax = plt.axes(projection='3d')

x_data = np.random.randint(0,100,(500,))
y_data = np.random.randint(0,100,(500,))
z_data = np.random.randint(0,100,(500,))

ax.scatter(x_data,y_data,z_data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Increasing figure quality
# https://blakeaw.github.io/2020-05-25-improve-matplotlib-notebook-inline-res/

# %%
ax = plt.axes(projection='3d')
x_data = np. arange (0, 50, 0.1)
y_data = np.arange (0, 50, 0.1)
z_data = x_data*y_data

ax.scatter(x_data, y_data, z_data, c='r', marker='o')
plt.show()

# %%
ax = plt.axes(projection='3d')
ax.plot(x_data, y_data, z_data)
plt.show()

# %%
ax = plt.axes(projection='3d')
ax.plot(x_data, y_data, z_data)

# set the labels and title of the plot 
ax.set_xlabel('x - axis')
ax.set_ylabel('y - axis')
ax.set_zlabel('z - axis')
ax.set_title('3D Line Plot')

# set the rotation of the 3d plot to be isometric
ax.view_init(15, 30)

# add a legend to the plot
ax.legend(['line1'], loc='upper left')

# %% [markdown]
# ## Surfaces

# %%
# Create a meshgrid of points
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)

# Calculate Z
Z = np.sin(X) * np.cos(Y)

ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, cmap='plasma', edgecolor='none')

plt.show()

# %% [markdown]
# ### Styles

# %% [markdown]
# Link: https://matplotlib.org/stable/gallery/style_sheets/style
# _sheets_reference.html
# Link:
# https://matplotlib.org/stable/tutorials/introductory/customizinq.html

# %%
from matplotlib import style
style.use("ggplot")

# Create a meshgrid of points
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)

# Calculate Z
Z = np.sin(X) * np.cos(Y)

ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, cmap='plasma', edgecolor='none')

plt.show()

# %% [markdown]
# ### Multiple Figures

# %%
x1, y1 = np.random.random(100), np.random.random(100)
x2, y2 = np.arange(100), np.random.random(100)
plt.figure(1)
plt.scatter(x1,y1)
plt.figure(2)
plt.plot(x2,y2)

# %% [markdown]
# ### Subplots
# does not work with plot_surface or 3D plots

# %%
fig, axs = plt.subplots(2,2)

axs[0,0].scatter(x1,y1)
axs[0,0].set_title('Plot 1')
axs[0,1].plot(x2,y2)
axs[0,1].set_title('Plot 2')
axs[1,0].scatter(np.sin(x1),y1)
axs[1,0].set_title('Plot 3')
fig.suptitle('Subplots')
# increase the spacing 
fig.tight_layout(pad=.5)

# %% [markdown]
# ### 3D Subplots

# %%
#3D subplots

# set up a figure twice as wide as it is tall
fig = plt.figure(figsize=plt.figaspect(0.5))

# =============
# First subplot
# =============
# set up the axes for the first plot
ax = fig.add_subplot(1, 2, 1, projection='3d')

# plot a 3D surface like in the example mplot3d/surface3d_demo
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='plasma', edgecolor='none',
                       linewidth=0, antialiased=False)
ax.set_zlim(-1.01, 1.01)
fig.colorbar(surf, shrink=0.5, aspect=10)

# ==============
# Second subplot
# ==============
# set up the axes for the second plot
ax = fig.add_subplot(1, 2, 2, projection='3d')

# plot a 3D wireframe like in the example mplot3d/wire3d_demo
ax.plot_wireframe(X, Y, Z, rstride=4, cstride=4)

fig.tight_layout(pad=1)
fig.patch.set_facecolor('#E5E5E5')
plt.show()

# %% [markdown]
# ## Interactive using ipywidgets

# %%
import ipywidgets

noise = np.random.randn(*x.shape)

def plt_fnc(w):
    x = np.linspace(-10, 10, 100)
    y = 2*x + w*noise
    plt.scatter(x,y)


ipywidgets.interact(plt_fnc, w=(0,10,0.1))
# Out:
# interactive(children=(FloatSlider(value=5.0, description='w', max=10.0), Output()), _dom_classes=('widget-inte…
# <function __main__.plt_fnc(w)>

# %%
from ipywidgets import interact, interactive, fixed

def plt_fnc2(azumith, elevation=80,time=0):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    # replot the surface with updated view angle
    ax.plot_surface(X, Y, Z*np.sin(time), cmap='plasma', edgecolor='none')
    # set the labels and title of the plot 
    ax.set_xlabel('x - axis')
    ax.set_ylabel('y - axis')
    ax.set_zlabel('z - axis')
    ax.set_title('3D Line Plot')

    # set the rotation of the 3d plot to be isometric
    ax.view_init(azumith, elevation)


ipywidgets.interact(plt_fnc2, azumith=(0,180,1),elevation=fixed(80),time = (0,10,0.1))
# Out:
# interactive(children=(IntSlider(value=90, description='azumith', max=180), FloatSlider(value=0.0, description=…
# <function __main__.plt_fnc2(azumith, elevation=80, time=0)>

# %% [markdown]
# ## Animation
# This code should work in a .py document but not a ipynb document

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='plasma', edgecolor='none')

for i in range(360):
    ax.clear()
    
    # set the labels and title of the plot 
    ax.set_xlabel('x - axis')
    ax.set_ylabel('y - axis')
    ax.set_zlabel('z - axis')
    ax.set_title('3D Line Plot')

    # replot the surface with updated view angle
    ax.plot_surface(X, Y, Z, cmap='plasma', edgecolor='none')

    # set the rotation of the 3d plot to be isometric
    ax.view_init(i, i)
    plt.pause(0.001)
    plt.clf()

plt.show()
